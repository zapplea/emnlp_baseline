# %%
from datetime import datetime

from nerd.data.util.mc_generator import McGenerator
from nerd.data.util.readers.BBNDataReader import BBNDataReader
from nerd.data.util.readers.WNUTDataReader import WNUTDataReader
from nerd.data.util.readers.JSONDataReader import JSONDataReader
from nerd.memory_retrieval.mention_driven_retrieval import MentionDrivenRetrieval
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-3c668c146723> in <module>()
#       5 from nerd.data.util.readers.WNUTDataReader import WNUTDataReader
#       6 from nerd.data.util.readers.JSONDataReader import JSONDataReader
# ----> 7 from nerd.memory_retrieval.mention_driven_retrieval import MentionDrivenRetrieval
#
# /home/nikhil/workspace/data61/dlnlp/nerd/memory_retrieval/mention_driven_retrieval.py in <module>()
#       3 from scipy import spatial
#       4
# ----> 5 from nerd.memory_retrieval.memory_retrieval import MemoryRetrieval
#       6 from nerd.util.string_util import StringUtil
#       7
#
# /home/nikhil/workspace/data61/dlnlp/nerd/memory_retrieval/memory_retrieval.py in <module>()
#       4 from datetime import datetime
#       5
# ----> 6 from memory_networks.MinHashMentionSearch import LSHMentionSearch
#       7
#       8 from nerd.memory_networks.M4Mat import M4Mat
#
# ModuleNotFoundError: No module named 'memory_networks'

# %%
data_set = 'JSON'
data_file_path = '/home/nikhil/Downloads/BBN/BBN/test.json'

# Note use model_path = None to save memory and not load text_embeddings if not required
# model_path = '/home/nikhil/workspace/data61/local/mwe_ner/ner/pretrained_models/word2vec/GoogleNews-vectors-negative300.bin'
model_path = '/home/nikhil/workspace/data61/local/wordvec/skipgram_v200_w5'
# model_path = None
model_is_binary = False

# Memory related data
db_path = '/home/nikhil/workspace/data61/local/db/skip_contxtEmb1000.db'
index_path = '/home/nikhil/workspace/data61/local/db/skip_contxtEmb1000.idx'
m4mat_emb_path = '/home/nikhil/workspace/data61/local/emb'

# gpu_1 settings
# db_path = '/media/data3tb2/yibing/nosqldb/database/skip_contxtEmb.db'
# index_path = '/media/data3tb2/yibing/nosqldb/database/skip_contxtEmb_lsh_index.idx'
# m4mat_emb_path = '/media/data3tb2/yibing/nosqldb/skip_mat'
# 
# model_path = '/media/data3tb2/yibing/nosqldb/skipgram_v200_w5'

# %%
# Initialise data
reader = WNUTDataReader

if data_set == 'BBN':
    reader = BBNDataReader
if data_set == 'JSON':
    reader = JSONDataReader

data = reader.readFile(data_file_path, modelPath=model_path, model_is_binary=model_is_binary)
mcGen = McGenerator(data, seed= 101)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-5cd9382947ee> in <module>()
#       1 # Initialise data
# ----> 2 reader = WNUTDataReader
#       3
#       4 if data_set == 'BBN':
#       5     reader = BBNDataReader
#
# NameError: name 'WNUTDataReader' is not defined

# %%
# Initialise memory
m4mat_emb_path = '/home/nikhil/workspace/data61/local/emb'
MentionDrivenRetrieval.init_memory(db_path=db_path, index_file_path=index_path, emb_context_dir=m4mat_emb_path)

# %%
# Get a positive candidate

mc = mcGen.getPositiveCandidate()

print('Sentence :')
print(data[mc.sentence_index].text)
print('Labels :')
print(data[mc.sentence_index].labels)


print('\n\n\n\n')
print(mc)

print('\n\n\n\n')
MentionDrivenRetrieval.retrieve_mentions(mc)
# Out:
# Sentence :
# ['``', 'In', 'Asia', ',', 'as', 'in', 'Europe', ',', 'a', 'new', 'order', 'is', 'taking', 'shape', ',', "''", 'Mr.', 'Baker', 'said', '.']
# Labels :
# ['OTHER', 'OTHER', '/LOCATION', 'OTHER', 'OTHER', 'OTHER', '/LOCATION', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER', 'OTHER
556), (847342, 'east europe', 0.5555555555555556), (887739, 'hotel europe', 0.5555555555555556), (1288029, 'nfl europe', 0.5555555555555556), (1350232, 'mini europe', 0.5555555555555556), (1484132, 'time europe', 0.5555555555555556), (1648629, 'nfl europe', 0.5555555555555556), (1703978, 'jim europe', 0.5555555555555556), (1772413, 'pagan europe', 0.5555555555555556), (1797790, 'stx europe', 0.5555555555555556), (1858679, 'offshore europe', 0.5555555555555556), (1868567, 'modern europe', 0.5555555555555556), (1870128, 'root into europe', 0.5555555555555556), (1928569, 'rail europe', 0.5555555555555556), (2027874, 'rand europe', 0.5555555555555556), (2169147, 'whole europe', 0.5555555555555556), (2194325, 'nbc europe', 0.5555555555555556), (2260707, 'mtv europe', 0.5555555555555556), (2280260, 'atari europe', 0.5555555555555556), (2343370, 'team europe', 0.5555555555555556), (2448802, 'cafe europe', 0.5555555555555556), (2471663, 'vat europe', 0.5555555555555556), (2536020, 'europe day', 0.5555555555555556), (2539551, 'amroy europe oy', 0.5555555555555556), (2667616, 'nbc europe', 0.5555555555555556), (2700048, 'mtv europe', 0.5555555555555556), (2844334, 'tgv europe', 0.5555555555555556), (2853608, 'northern europe', 0.5555555555555556), (2891676, 'aci europe', 0.5555555555555556), (2934788, 'tommy europe', 0.5555555555555556), (9171, 'western europe', 0.5), (30291, 'western europe', 0.5), (32257, 'southern europe', 0.5), (263991, 'europe a nation', 0.5), (289524, 'war in europe', 0.5), (338618, 'europe first', 0.5), (370316, 'western europe', 0.5), (462594, 'iron age europe', 0.5), (640687, 'western europe', 0.5), (718113, 'western europe', 0.5), (785359, 'song for europe', 0.5), (789574, 'war in europe', 0.5), (804391, 'europe live tour', 0.5), (877002, 'war in europe', 0.5), (894463, 'europe NUM4', 0.5), (990068, 'europe airpost', 0.5), (1034718, 'europe NUM1', 0.5), (1048148, 'southwest europe', 0.5), (1187034, 'toyota team europe', 0.5), (1291752, 'europe NUM2', 0.5), (1377177, 'college f europe', 0.5), (1377363, 'europe NUM4', 0.5), (1380190, 'northern europe .', 0.5), ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-e1a4faf07c86> in <module>()
#      13
#      14 print('\n\n\n\n')
# ---> 15 MentionDrivenRetrieval.retrieve_mentions(mc)
#
# /home/nikhil/workspace/data61/local/mwe_ner/ner/memory_retrieval/mention_driven_retrieval.py in retrieve_mentions(cls, mention_candidate, k)
#     123
#     124         # 4. Retrieve top k ranked contexts based on the mention_ids
# --> 125         ranked_mention_contexts = cls._get_ranked_contexts_by_mention_ids(ranked_mentions, mention_embedding, k)
#     126         print('Ranked context retrieval')
#     127         print(ranked_mention_contexts)
#
# /home/nikhil/workspace/data61/local/mwe_ner/ner/memory_retrieval/mention_driven_retrieval.py in _get_ranked_contexts_by_mention_ids(cls, ref_mentions, mention_context_embedding, k)
#      44
#      45                 # Retrieve corresponding embedding from mmat
# ---> 46                 ref_context_embedding = cls.mmat[mmat_id:]
#      47                 context_similarity = similarity_measure(mention_context_embedding, ref_context_embedding)
#      48                 weighted_score = cls._get_weighted_score(m_similarity, context_similarity)
#
# /home/nikhil/workspace/data61/local/mwe_ner/memory_networks/M4Mat.py in __getitem__(self, mat_index)
#      89         '''
#      90
# ---> 91         row_max_id = mat_index[0]
#      92
#      93
#
# TypeError: 'slice' object is not subscriptable
